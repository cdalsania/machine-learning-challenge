# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.16.0)

# %%
# install joblib. This will be used to save the model. 
# Restart the kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\dalsa\anaconda3\envs\pythondata\lib\site-packages (0.16.0)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Data Exploration

# %%
df.groupby('koi_disposition').count()
# Out:
#                  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# koi_disposition
# CANDIDATE                 1687           1687           1687           1687
# CONFIRMED                 1800           1800           1800           1800
# FALSE POSITIVE            3504           3504           3504           3504
#
#                  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# koi_disposition
# CANDIDATE              1687             1687             1687         1687
# CONFIRMED              1800             1800             1800         1800
# FALSE POSITIVE         3504             3504             3504         3504
#
#                  koi_time0bk_err1  koi_time0bk_err2  ...  koi_steff_err2  \
# koi_disposition                                      ...
# CANDIDATE                    1687              1687  ...            1687
# CONFIRMED                    1800              1800  ...            1800
# FALSE POSITIVE               3504              3504  ...            3504
#
#                  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# koi_disposition
# CANDIDATE             1687            1687            1687      1687
# CONFIRMED             1800            1800            1800      1800
# FALSE POSITIVE        3504            3504            3504      3504
#
#                  koi_srad_err1  koi_srad_err2    ra   dec  koi_kepmag
# koi_disposition
# CANDIDATE                 1687           1687  1687  1687        1687
# CONFIRMED                 1800           1800  1800  1800        1800
# FALSE POSITIVE            3504           3504  3504  3504        3504
#
# [3 rows x 40 columns]

# %%
grouped_df = df[['koi_disposition','koi_fpflag_nt']].groupby('koi_disposition').count()
grouped_df = grouped_df.rename(columns={"koi_fpflag_nt":"Count"})
grouped_df.plot(kind="bar")

# %% [markdown]
# # Selecting all 40 features (columns)

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
# Set features. This will also be used as x values.
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
       'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
       'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
       'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
       'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
       'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
       'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
       'koi_kepmag']]
selected_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 40 columns]

# %% [markdown]
# ## Create a Train Test Split
# ### Use koi_disposition for the y value

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = selected_features
y = df[['koi_disposition']].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (6991, 40) (6991, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y.flatten())
encoded_y = label_encoder.transform(y.flatten())
encoded_y
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
encoded_y = encoded_y.reshape(-1, 1)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ...
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------

# %%
# Use sklearn's `train_test_split` to split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %%
y_train.shape
# Out:
# (5243, 1)

# %% [markdown]
# ## Pre-processing
# #### Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %% [markdown]
# ## Train the Model

# %%
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression(max_iter=1000)
model2
# Out:
# LogisticRegression(max_iter=1000)

# %%
model2.fit(X_train_scaled, y_train.flatten())
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8479877932481403
# Testing Data Score: 0.8443935926773455

# %% [markdown]
# ### Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
model2.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
# Create the GridSearchCV model

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'penalty': ['l2','none'],
              'class_weight': [{0:1, 1:1, 2:2}, "balanced", None]}
grid2 = GridSearchCV(model2, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid2.fit(X_train_scaled, y_train.flatten())
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.856, total=   1.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.843, total=   1.7s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.859, total=   1.7s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.827, total=   1.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.839, total=   1.9s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.894, total=   6.1s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   5.8s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.891, total=   5.8s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.870, total=   5.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.883, total=   4.4s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.861, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.841, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.859, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.835, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.844, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.888, total=   4.4s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.886, total=   4.3s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.897, total=   4.4s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.873, total=   4.5s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.885, total=   4.7s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.856, total=   1.3s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.843, total=   1.1s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.858, total=   0.9s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.827, total=   1.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.839, total=   1.1s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.895, total=   5.1s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.884, total=   5.4s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.894, total=   5.0s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.870, total=   5.2s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.885, total=   5.6s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.879, total=   3.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.855, total=   2.5s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.877, total=   2.4s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.849, total=   3.2s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.864, total=   2.2s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.894, total=   5.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   5.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.891, total=   5.0s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.870, total=   5.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.883, total=   4.9s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.877, total=   2.4s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.860, total=   2.6s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.881, total=   3.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.846, total=   2.6s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.863, total=   2.5s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.888, total=   5.1s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.886, total=   5.0s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.897, total=   5.3s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.873, total=   5.3s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.885, total=   5.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.877, total=   2.5s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.855, total=   2.7s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.877, total=   2.9s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.846, total=   2.2s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.864, total=   2.5s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.895, total=   5.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.884, total=   5.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.894, total=   5.2s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.870, total=   5.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight=None, penalty=none, score=0.885, total=   5.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.882, total=   3.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.861, total=   4.2s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.883, total=   3.4s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.854, total=   4.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.865, total=   3.7s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.894, total=   5.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   5.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.891, total=   5.5s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.870, total=   5.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.883, total=   5.4s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.883, total=   4.7s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.868, total=   3.8s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.888, total=   3.9s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.858, total=   4.7s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.867, total=   4.3s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.888, total=   5.6s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.886, total=   5.8s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.897, total=   5.5s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.873, total=   5.8s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.885, total=   5.8s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.882, total=   3.5s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.860, total=   3.7s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.885, total=   2.9s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.851, total=   3.3s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV] . C=10, class_weight=None, penalty=l2, score=0.865, total=   4.4s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.895, total=   5.4s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.884, total=   5.5s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.894, total=   5.9s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.870, total=   6.0s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight=None, penalty=none, score=0.885, total=   5.7s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.894, total=   5.7s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.872, total=   5.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.890, total=   6.0s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.875, total=   5.7s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.894, total=   5.8s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.867, total=   5.9s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.874, total=   6.2s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.888, total=   5.7s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.886, total=   5.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.897, total=   5.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.873, total=   5.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.885, total=   5.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.891, total=   5.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.872, total=   5.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.889, total=   5.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.861, total=   5.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV] . C=50, class_weight=None, penalty=l2, score=0.874, total=   5.3s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.895, total=   5.4s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.884, total=   5.4s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.894, total=   5.3s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.870, total=   5.4s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  8.7min finished
# [CV]  C=50, class_weight=None, penalty=none, score=0.885, total=   5.4s
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(estimator=LogisticRegression(max_iter=1000),
#              param_grid={'C': [1, 5, 10, 50],
#                          'class_weight': [{0: 1, 1: 1, 2: 2}, 'balanced', None],
#                          'penalty': ['l2', 'none']},
#              verbose=3)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'C': 1, 'class_weight': 'balanced', 'penalty': 'none'}
# 0.8857499690726902

# %%
# Make predictions with the hypertuned model
predictions = grid2.predict(X_test_scaled)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test.flatten(), predictions,
                            target_names=["CANDIDATE", "CONFIRMED","FALSE POSITIVE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.80      0.72      0.76       411
#      CONFIRMED       0.78      0.84      0.81       484
# FALSE POSITIVE       0.98      0.99      0.99       853
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.85      0.85      1748
#   weighted avg       0.88      0.88      0.88      1748

# %%
# from sklearn.linear_model import LogisticRegression
hypertuned_model = LogisticRegression(C=1, class_weight=None, max_iter=1000, penalty='none')
hypertuned_model
# Out:
# LogisticRegression(C=1, max_iter=1000, penalty='none')

# %%
hypertuned_model.fit(X_train_scaled, y_train.flatten())
# Out:
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1, max_iter=1000, penalty='none')

# %%
print(f"Training Data Score: {hypertuned_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {hypertuned_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8899485027655922
# Testing Data Score: 0.8844393592677345

# %% [markdown]
# ## Feature Selection
# #### Method 1 - Using Select From Model (SFM)

# %%
from sklearn.feature_selection import SelectFromModel

sfm = SelectFromModel(model2, max_features=40)
sfm.fit(X_train_scaled, y_train.flatten())
feature_idx = sfm.get_support()
feature_name = selected_features.columns[feature_idx]
feature_name
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#        'koi_period', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_teq', 'koi_model_snr', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg_err2'],
#       dtype='object')

# %% [markdown]
# ### Choosing features from SFM

# %%
# Set top features suggested by SFM. This will be used as x values.
sfm_features = df[[ 
    'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
       'koi_period', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1',
       'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
       'koi_teq', 'koi_model_snr', 'koi_steff_err1', 'koi_steff_err2',
       'koi_slogg_err2']]
sfm_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_time0bk_err1  koi_time0bk_err2  koi_impact_err1  koi_duration  \
# 0             0.003520         -0.003520            0.059       4.50700
# 1             0.000581         -0.000581            5.126       1.78220
# 2             0.000115         -0.000115            0.115       2.40641
# 3             0.001130         -0.001130            0.235       1.65450
# 4             0.001900         -0.001900            0.139       3.14020
# ...                ...               ...              ...           ...
# 6986          0.015700         -0.015700            0.023       4.80600
# 6987          0.000170         -0.000170            0.051       3.22210
# 6988          0.007690         -0.007690            0.423       3.11400
# 6989          0.002850         -0.002850            0.309       0.86500
# 6990          0.010800         -0.010800            0.323       3.07800
#
#       koi_duration_err1  koi_duration_err2  koi_depth  koi_teq  koi_model_snr  \
# 0               0.11600           -0.11600      874.8      443           25.8
# 1               0.03410           -0.03410    10829.0      638           76.3
# 2               0.00537           -0.00537     8079.2     1395          505.6
# 3               0.04200           -0.04200      603.3     1406           40.9
# 4               0.06730           -0.06730      686.0     1160           40.2
# ...                 ...                ...        ...      ...            ...
# 6986            0.63400           -0.63400       87.7      929            8.4
# 6987            0.01740           -0.01740     1579.2     2088          453.3
# 6988            0.22900           -0.22900       48.5     1608           10.6
# 6989            0.16200           -0.16200      103.6     2218           12.3
# 6990            0.28300           -0.28300       76.7     1266            8.2
#
#       koi_steff_err1  koi_steff_err2  koi_slogg_err2
# 0                 81             -81          -0.096
# 1                158            -176          -0.176
# 2                157            -174          -0.168
# 3                169            -211          -0.210
# 4                189            -232          -0.229
# ...              ...             ...             ...
# 6986             169            -152          -0.189
# 6987             139            -166          -0.196
# 6988             165            -220          -0.224
# 6989             193            -236          -0.224
# 6990             158            -225          -0.216
#
# [6991 rows x 17 columns]

# %% [markdown]
# ### Create Train Test Split with SFM features

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X_sfm = sfm_features
y_sfm = df[['koi_disposition']].values.reshape(-1, 1)

print("Shape: ", X_sfm.shape, y_sfm.shape)
# Out:
# Shape:  (6991, 17) (6991, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_sfm.flatten())
encoded_y_sfm = label_encoder.transform(y_sfm.flatten())
encoded_y_sfm
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
encoded_y_sfm = encoded_y_sfm.reshape(-1, 1)
encoded_y_sfm
# Out:
# array([[1],
#        [2],
#        [2],
#        ...,
#        [0],
#        [2],
#        [2]])

# %%
for label, original_class in zip(encoded_y_sfm, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ...
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------

# %%
# Use sklearn's `train_test_split` to split the data into training and testing
from sklearn.model_selection import train_test_split

X_train_sfm, X_test_sfm, y_train_sfm, y_test_sfm = train_test_split(X_sfm, encoded_y_sfm, random_state=42)

# %% [markdown]
# ### Pre-processing - SFM features data

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_minmax_sfm = MinMaxScaler().fit(X_train_sfm)

X_train_scaled_sfm = X_minmax_sfm.transform(X_train_sfm)
X_test_scaled_sfm = X_minmax_sfm.transform(X_test_sfm)

# %% [markdown]
# ### Train the Model with SFM Features

# %%
from sklearn.linear_model import LogisticRegression
model_sfm = LogisticRegression(max_iter=500)
model_sfm
# Out:
# LogisticRegression(max_iter=500)

# %%
model_sfm.fit(X_train_scaled_sfm, y_train_sfm.flatten())
# Out:
# LogisticRegression(max_iter=500)

# %%
print(f"Training Data Score: {model_sfm.score(X_train_scaled_sfm, y_train_sfm)}")
print(f"Testing Data Score: {model_sfm.score(X_test_scaled_sfm, y_test_sfm)}")
# Out:
# Training Data Score: 0.8466526797634942
# Testing Data Score: 0.8323798627002288

# %% [markdown]
# ### Hyperparameter Tuning on SFM Features

# %%
model_sfm.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
# Create the GridSearchCV model

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid_sfm = {'C': [1, 5, 10, 50],
              'penalty': ['l2', 'none'],
              'class_weight': [{0:1, 1:1, 2:2}, "balanced", None]}
grid2_sfm = GridSearchCV(model_sfm, param_grid_sfm, verbose=3)

# %%
# Train the model with GridSearch
grid2_sfm.fit(X_train_scaled_sfm, y_train_sfm.flatten())
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.858, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.836, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.852, total=   0.5s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.826, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.833, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.895, total=   2.1s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   2.1s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   2.1s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   2.1s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   2.2s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.862, total=   0.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.836, total=   0.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.855, total=   0.9s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.830, total=   0.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.841, total=   0.8s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.893, total=   2.0s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.881, total=   2.1s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.889, total=   1.8s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.872, total=   2.0s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.882, total=   2.0s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.858, total=   0.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.836, total=   0.5s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.852, total=   0.7s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.826, total=   0.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.833, total=   0.6s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.893, total=   2.0s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.880, total=   2.1s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.886, total=   1.9s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.870, total=   2.0s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.885, total=   2.2s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.884, total=   1.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.856, total=   1.2s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.865, total=   1.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.846, total=   1.4s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.858, total=   0.9s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.895, total=   1.8s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   2.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   2.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   2.0s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   2.2s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.889, total=   1.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.859, total=   1.2s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.869, total=   1.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.848, total=   1.4s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.860, total=   1.1s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.893, total=   2.1s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.881, total=   2.1s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.889, total=   1.9s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.872, total=   2.2s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.882, total=   2.1s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.884, total=   1.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.856, total=   1.1s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.864, total=   1.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.846, total=   1.4s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.859, total=   1.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.893, total=   2.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.880, total=   2.2s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.886, total=   2.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.870, total=   1.9s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight=None, penalty=none, score=0.885, total=   2.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.891, total=   1.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.862, total=   1.7s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.873, total=   1.8s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.860, total=   1.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.865, total=   1.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.895, total=   2.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   1.9s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   1.9s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   2.1s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   1.9s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.891, total=   1.8s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.867, total=   1.5s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.870, total=   2.0s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.857, total=   1.8s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.870, total=   1.6s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.893, total=   1.9s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.881, total=   2.1s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.889, total=   1.9s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.872, total=   1.9s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.882, total=   2.1s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.891, total=   1.7s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.863, total=   1.8s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.873, total=   1.8s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.859, total=   1.9s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.865, total=   1.6s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.893, total=   2.1s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.880, total=   2.0s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.886, total=   2.1s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.870, total=   1.9s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight=None, penalty=none, score=0.885, total=   1.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.895, total=   2.1s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.881, total=   2.1s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.881, total=   1.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.879, total=   1.8s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.884, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.871, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.877, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.893, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.881, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.889, total=   2.0s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.872, total=   2.1s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.882, total=   1.8s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.895, total=   2.1s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.880, total=   1.9s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.879, total=   2.2s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV] . C=50, class_weight=None, penalty=l2, score=0.868, total=   1.8s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV] . C=50, class_weight=None, penalty=l2, score=0.879, total=   1.9s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.893, total=   2.0s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.880, total=   2.1s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.886, total=   2.1s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.870, total=   1.9s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  3.4min finished
# [CV]  C=50, class_weight=None, penalty=none, score=0.885, total=   2.0s
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(estimator=LogisticRegression(max_iter=500),
#              param_grid={'C': [1, 5, 10, 50],
#                          'class_weight': [{0: 1, 1: 1, 2: 2}, 'balanced', None],
#                          'penalty': ['l2', 'none']},
#              verbose=3)

# %%
print(grid2_sfm.best_params_)
print(grid2_sfm.best_score_)
# Out:
# {'C': 1, 'class_weight': 'balanced', 'penalty': 'none'}
# 0.8834611662142791

# %%
# Make predictions with the hypertuned model
predictions_sfm = grid2_sfm.predict(X_test_scaled_sfm)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test_sfm.flatten(), predictions_sfm,
                            target_names=["CANDIDATE", "CONFIRMED","FALSE POSITIVE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.79      0.70      0.74       411
#      CONFIRMED       0.77      0.83      0.80       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.84      0.84      1748
#   weighted avg       0.88      0.88      0.88      1748

# %%
hypertuned_model_sfm = LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')
hypertuned_model_sfm
# Out:
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')

# %%
hypertuned_model_sfm.fit(X_train_scaled_sfm, y_train_sfm.flatten())
# Out:
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')

# %%
print(f"Training Data Score: {hypertuned_model_sfm.score(X_train_scaled_sfm, y_train_sfm)}")
print(f"Testing Data Score: {hypertuned_model_sfm.score(X_test_scaled_sfm, y_test_sfm)}")
# Out:
# Training Data Score: 0.884798779324814
# Testing Data Score: 0.8804347826086957

# %% [markdown]
# ## Method 3 - Using Recursive Feature Elimination (RFE)

# %%
from sklearn.feature_selection import RFE
predictors = X_train_scaled
selector = RFE(model2, n_features_to_select = 1)
selector = selector.fit(predictors, y_train.flatten());

# %%
order = selector.ranking_
order
# Out:
# array([ 4,  6,  5,  7, 11, 19, 21, 23,  3,  9, 29, 13, 33, 16,  1,  2, 15,
#        38, 39, 36, 34, 40, 10, 35, 32, 37, 12, 20, 22,  8, 18, 17, 25, 14,
#        28, 24, 30, 27, 26, 31])

# %%
feature_ranks = []
column_num = 0
for i in order:
    feature_ranks.append(f"{i}. {selected_features.columns[column_num]}")
    column_num += 1
feature_ranks
# Out:
# ['4. koi_fpflag_nt',
#  '6. koi_fpflag_ss',
#  '5. koi_fpflag_co',
#  '7. koi_fpflag_ec',
#  '11. koi_period',
#  '19. koi_period_err1',
#  '21. koi_period_err2',
#  '23. koi_time0bk',
#  '3. koi_time0bk_err1',
#  '9. koi_time0bk_err2',
#  '29. koi_impact',
#  '13. koi_impact_err1',
#  '33. koi_impact_err2',
#  '16. koi_duration',
#  '1. koi_duration_err1',
#  '2. koi_duration_err2',
#  '15. koi_depth',
#  '38. koi_depth_err1',
#  '39. koi_depth_err2',
#  '36. koi_prad',
#  '34. koi_prad_err1',
#  '40. koi_prad_err2',
#  '10. koi_teq',
#  '35. koi_insol',
#  '32. koi_insol_err1',
#  '37. koi_insol_err2',
#  '12. koi_model_snr',
#  '20. koi_tce_plnt_num',
#  '22. koi_steff',
#  '8. koi_steff_err1',
#  '18. koi_steff_err2',
#  '17. koi_slogg',
#  '25. koi_slogg_err1',
#  '14. koi_slogg_err2',
#  '28. koi_srad',
#  '24. koi_srad_err1',
#  '30. koi_srad_err2',
#  '27. ra',
#  '26. dec',
#  '31. koi_kepmag']

# %% [markdown]
# ### Choosing Top 10 features from RFE

# %%
# Set top 10 features suggested by RFE. This will be used as x values.
top_10_features = df[[ 
    'koi_duration_err1',
'koi_duration_err2',
'koi_time0bk_err1',
'koi_fpflag_nt',
'koi_fpflag_ss',
'koi_fpflag_co',
'koi_fpflag_ec',
'koi_steff_err1',
'koi_time0bk_err2',
'koi_teq',]]
top_10_features
# Out:
#       koi_duration_err1  koi_duration_err2  koi_time0bk_err1  koi_fpflag_nt  \
# 0               0.11600           -0.11600          0.003520              0
# 1               0.03410           -0.03410          0.000581              0
# 2               0.00537           -0.00537          0.000115              0
# 3               0.04200           -0.04200          0.001130              0
# 4               0.06730           -0.06730          0.001900              0
# ...                 ...                ...               ...            ...
# 6986            0.63400           -0.63400          0.015700              0
# 6987            0.01740           -0.01740          0.000170              0
# 6988            0.22900           -0.22900          0.007690              0
# 6989            0.16200           -0.16200          0.002850              0
# 6990            0.28300           -0.28300          0.010800              0
#
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_steff_err1  \
# 0                 0              0              0              81
# 1                 1              0              0             158
# 2                 1              0              0             157
# 3                 0              0              0             169
# 4                 0              0              0             189
# ...             ...            ...            ...             ...
# 6986              0              0              1             169
# 6987              1              1              0             139
# 6988              0              0              0             165
# 6989              0              1              0             193
# 6990              0              1              1             158
#
#       koi_time0bk_err2  koi_teq
# 0            -0.003520      443
# 1            -0.000581      638
# 2            -0.000115     1395
# 3            -0.001130     1406
# 4            -0.001900     1160
# ...                ...      ...
# 6986         -0.015700      929
# 6987         -0.000170     2088
# 6988         -0.007690     1608
# 6989         -0.002850     2218
# 6990         -0.010800     1266
#
# [6991 rows x 10 columns]

# %% [markdown]
# ### Create Train Test Split with Top 10 features

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X_top10 = top_10_features
y_top10 = df[['koi_disposition']].values.reshape(-1, 1)

print("Shape: ", X_top10.shape, y_top10.shape)
# Out:
# Shape:  (6991, 10) (6991, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_top10.flatten())
encoded_y_top10 = label_encoder.transform(y_top10.flatten())
encoded_y_top10
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
encoded_y_top10 = encoded_y_top10.reshape(-1, 1)
encoded_y_top10
# Out:
# array([[1],
#        [2],
#        [2],
#        ...,
#        [0],
#        [2],
#        [2]])

# %%
for label, original_class in zip(encoded_y_top10, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ...
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------

# %%
# Use sklearn's `train_test_split` to split the data into training and testing
from sklearn.model_selection import train_test_split

X_train_top10, X_test_top10, y_train_top10, y_test_top10 = train_test_split(X_top10, encoded_y_top10, random_state=42)

# %% [markdown]
# ### Pre-processing - Top 10 features data

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_minmax_top10 = MinMaxScaler().fit(X_train_top10)

X_train_scaled_top10 = X_minmax_top10.transform(X_train_top10)
X_test_scaled_top10 = X_minmax_top10.transform(X_test_top10)

# %% [markdown]
# ### Train the Model with Top 10 Features

# %%
from sklearn.linear_model import LogisticRegression
model_top10 = LogisticRegression(max_iter=1000)
model_top10
# Out:
# LogisticRegression(max_iter=1000)

# %%
model_top10.fit(X_train_scaled_top10, y_train_top10.flatten())
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(f"Training Data Score: {model_top10.score(X_train_scaled_top10, y_train_top10)}")
print(f"Testing Data Score: {model_top10.score(X_test_scaled_top10, y_test_top10)}")
# Out:
# Training Data Score: 0.8460804882700744
# Testing Data Score: 0.8335240274599542

# %% [markdown]
# ### Hyperparameter Tuning on Top 10 Features

# %%
model_top10.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
# Create the GridSearchCV model

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid_top10 = {'C': [1, 5, 10, 50],
              'penalty': ['l2', 'none'],
              'class_weight': [{0:1, 1:1, 2:2}, "balanced", None]}
grid2_top10 = GridSearchCV(model_top10, param_grid_top10, verbose=3)

# %%
# Train the model with GridSearch
grid2_top10.fit(X_train_scaled_top10, y_train_top10.flatten())
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.858, total=   0.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.840, total=   0.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.856, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.826, total=   0.3s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.838, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   1.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.866, total=   0.9s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.874, total=   1.2s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.848, total=   1.3s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.863, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.859, total=   0.5s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.846, total=   0.5s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.859, total=   0.6s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.827, total=   0.4s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.839, total=   0.5s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.879, total=   1.4s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.865, total=   1.7s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.875, total=   1.7s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.847, total=   1.5s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.862, total=   1.9s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.858, total=   0.5s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.840, total=   0.4s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.856, total=   0.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.826, total=   0.5s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.838, total=   0.6s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.880, total=   1.5s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.865, total=   1.2s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.874, total=   1.6s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.848, total=   1.7s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.863, total=   1.5s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.875, total=   0.8s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.851, total=   0.9s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.863, total=   0.8s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.837, total=   1.0s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.860, total=   0.8s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   1.9s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.866, total=   1.1s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.874, total=   1.4s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.848, total=   1.5s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.863, total=   1.1s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.878, total=   1.0s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.853, total=   0.9s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.863, total=   0.9s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.834, total=   1.0s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.863, total=   0.8s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.879, total=   1.4s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.865, total=   1.9s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.875, total=   2.0s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.847, total=   1.7s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.862, total=   2.2s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.875, total=   0.9s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.851, total=   0.8s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.863, total=   1.1s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.837, total=   1.0s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.860, total=   0.9s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.880, total=   1.6s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.865, total=   1.3s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.874, total=   1.8s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.848, total=   1.9s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.863, total=   1.4s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.881, total=   1.2s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.852, total=   1.2s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.864, total=   1.0s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.841, total=   1.0s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.862, total=   1.2s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   1.9s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.866, total=   1.0s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.874, total=   1.3s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.848, total=   1.4s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.863, total=   1.1s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.882, total=   1.5s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.855, total=   1.4s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.867, total=   1.4s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.843, total=   1.1s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.858, total=   1.2s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.879, total=   1.6s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.865, total=   1.9s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.875, total=   2.0s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.847, total=   1.6s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.862, total=   2.1s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.881, total=   1.2s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.852, total=   1.1s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.864, total=   1.0s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.842, total=   1.5s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.862, total=   1.0s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.880, total=   1.6s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.865, total=   1.3s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.874, total=   1.8s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.848, total=   1.9s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.863, total=   1.4s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.883, total=   1.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.865, total=   1.8s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.867, total=   1.8s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.846, total=   1.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.860, total=   2.1s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.880, total=   2.0s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.866, total=   1.1s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.874, total=   1.5s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.848, total=   1.6s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.863, total=   1.2s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.880, total=   2.1s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.862, total=   2.0s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.869, total=   2.6s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.843, total=   2.0s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.859, total=   1.8s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.879, total=   1.6s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.865, total=   2.0s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.875, total=   1.9s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.847, total=   1.6s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.862, total=   2.0s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.882, total=   1.8s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.865, total=   1.8s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.867, total=   2.1s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.846, total=   2.2s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.860, total=   2.1s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.880, total=   1.6s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.865, total=   1.3s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.874, total=   1.8s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.848, total=   1.9s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.863, total=   1.5s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  2.7min finished
# GridSearchCV(estimator=LogisticRegression(max_iter=1000),
#              param_grid={'C': [1, 5, 10, 50],
#                          'class_weight': [{0: 1, 1: 1, 2: 2}, 'balanced', None],
#                          'penalty': ['l2', 'none']},
#              verbose=3)

# %%
print(grid2_top10.best_params_)
print(grid2_top10.best_score_)
# Out:
# {'C': 1, 'class_weight': {0: 1, 1: 1, 2: 2}, 'penalty': 'none'}
# 0.8661031225667484

# %%
# Make predictions with the hypertuned model
predictions_top10 = grid2_top10.predict(X_test_scaled_top10)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test_top10.flatten(), predictions_top10,
                            target_names=["CANDIDATE", "CONFIRMED","FALSE POSITIVE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.76      0.65      0.70       411
#      CONFIRMED       0.74      0.80      0.77       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.86      1748
#      macro avg       0.83      0.82      0.82      1748
#   weighted avg       0.86      0.86      0.86      1748

# %%
hypertuned_model_top10 = LogisticRegression(C=1, class_weight={0: 1, 1: 1, 2: 2}, max_iter=1000, penalty='none')
hypertuned_model_top10
# Out:
# LogisticRegression(C=1, class_weight={0: 1, 1: 1, 2: 2}, max_iter=1000,
#                    penalty='none')

# %%
hypertuned_model_top10.fit(X_train_scaled_top10, y_train_top10.flatten())
# Out:
# LogisticRegression(C=1, class_weight={0: 1, 1: 1, 2: 2}, max_iter=1000,
#                    penalty='none')

# %%
print(f"Training Data Score: {hypertuned_model_top10.score(X_train_scaled_top10, y_train_top10)}")
print(f"Testing Data Score: {hypertuned_model_top10.score(X_test_scaled_top10, y_test_top10)}")
# Out:
# Training Data Score: 0.8685866870112531
# Testing Data Score: 0.8627002288329519

# %% [markdown]
# ### Choosing Top 17 features from RFE

# %%
# Set top 17 features suggested by RFE. This will be used as x values.
top_17_features = df[[ 
 'koi_duration_err1',
'koi_duration_err2',
'koi_time0bk_err1',
'koi_fpflag_nt',
'koi_fpflag_ss',
'koi_fpflag_co',
'koi_fpflag_ec',
'koi_steff_err1',
'koi_time0bk_err2',
'koi_teq',
'koi_period',
'koi_model_snr',
'koi_impact_err1',
'koi_slogg_err2',
'koi_depth',
'koi_duration',
'koi_slogg']]

top_17_features
# Out:
#       koi_duration_err1  koi_duration_err2  koi_time0bk_err1  koi_fpflag_nt  \
# 0               0.11600           -0.11600          0.003520              0
# 1               0.03410           -0.03410          0.000581              0
# 2               0.00537           -0.00537          0.000115              0
# 3               0.04200           -0.04200          0.001130              0
# 4               0.06730           -0.06730          0.001900              0
# ...                 ...                ...               ...            ...
# 6986            0.63400           -0.63400          0.015700              0
# 6987            0.01740           -0.01740          0.000170              0
# 6988            0.22900           -0.22900          0.007690              0
# 6989            0.16200           -0.16200          0.002850              0
# 6990            0.28300           -0.28300          0.010800              0
#
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_steff_err1  \
# 0                 0              0              0              81
# 1                 1              0              0             158
# 2                 1              0              0             157
# 3                 0              0              0             169
# 4                 0              0              0             189
# ...             ...            ...            ...             ...
# 6986              0              0              1             169
# 6987              1              1              0             139
# 6988              0              0              0             165
# 6989              0              1              0             193
# 6990              0              1              1             158
#
#       koi_time0bk_err2  koi_teq  koi_period  koi_model_snr  koi_impact_err1  \
# 0            -0.003520      443   54.418383           25.8            0.059
# 1            -0.000581      638   19.899140           76.3            5.126
# 2            -0.000115     1395    1.736952          505.6            0.115
# 3            -0.001130     1406    2.525592           40.9            0.235
# 4            -0.001900     1160    4.134435           40.2            0.139
# ...                ...      ...         ...            ...              ...
# 6986         -0.015700      929    8.589871            8.4            0.023
# 6987         -0.000170     2088    0.527699          453.3            0.051
# 6988         -0.007690     1608    1.739849           10.6            0.423
# 6989         -0.002850     2218    0.681402           12.3            0.309
# 6990         -0.010800     1266    4.856035            8.2            0.323
#
#       koi_slogg_err2  koi_depth  koi_duration  koi_slogg
# 0             -0.096      874.8       4.50700      4.467
# 1             -0.176    10829.0       1.78220      4.544
# 2             -0.168     8079.2       2.40641      4.564
# 3             -0.210      603.3       1.65450      4.438
# 4             -0.229      686.0       3.14020      4.486
# ...              ...        ...           ...        ...
# 6986          -0.189       87.7       4.80600      4.296
# 6987          -0.196     1579.2       3.22210      4.529
# 6988          -0.224       48.5       3.11400      4.444
# 6989          -0.224      103.6       0.86500      4.447
# 6990          -0.216       76.7       3.07800      4.385
#
# [6991 rows x 17 columns]

# %% [markdown]
# ### Create Train Test Split with Top 17 features

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X_top17 = top_17_features
y_top17 = df[['koi_disposition']].values.reshape(-1, 1)

print("Shape: ", X_top17.shape, y_top17.shape)
# Out:
# Shape:  (6991, 17) (6991, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_top17.flatten())
encoded_y_top17 = label_encoder.transform(y_top17.flatten())
encoded_y_top17
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
encoded_y_top17 = encoded_y_top17.reshape(-1, 1)
encoded_y_top17
# Out:
# array([[1],
#        [2],
#        [2],
#        ...,
#        [0],
#        [2],
#        [2]])

# %%
for label, original_class in zip(encoded_y_top17, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ...
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CONFIRMED']
# Encoded Label: [1]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['CANDIDATE']
# Encoded Label: [0]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------
# Original Class: ['FALSE POSITIVE']
# Encoded Label: [2]
# ------------

# %%
# Use sklearn's `train_test_split` to split the data into training and testing
from sklearn.model_selection import train_test_split

X_train_top17, X_test_top17, y_train_top17, y_test_top17 = train_test_split(X_top17, encoded_y_top17, random_state=42)

# %% [markdown]
# ### Pre-processing - Top 17 features data

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_minmax_top17 = MinMaxScaler().fit(X_train_top17)

X_train_scaled_top17 = X_minmax_top17.transform(X_train_top17)
X_test_scaled_top17 = X_minmax_top17.transform(X_test_top17)

# %% [markdown]
# ### Train the Model with Top 17 Features

# %%
from sklearn.linear_model import LogisticRegression
model_top17 = LogisticRegression(max_iter=1000)
model_top17
# Out:
# LogisticRegression(max_iter=1000)

# %%
model_top17.fit(X_train_scaled_top17, y_train_top17.flatten())
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(f"Training Data Score: {model_top17.score(X_train_scaled_top17, y_train_top17)}")
print(f"Testing Data Score: {model_top17.score(X_test_scaled_top17, y_test_top17)}")
# Out:
# Training Data Score: 0.8483692542437535
# Testing Data Score: 0.8352402745995423

# %% [markdown]
# ### Hyperparameter Tuning on Top 17 Features

# %%
model_top17.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
# Create the GridSearchCV model

# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid_top17 = {'C': [1, 5, 10, 50],
              'penalty': ['l2', 'none'],
              'class_weight': [{0:1, 1:1, 2:2}, "balanced", None]}
grid2_top17 = GridSearchCV(model_top17, param_grid_top17, verbose=3)

# %%
# Train the model with GridSearch
grid2_top17.fit(X_train_scaled_top17, y_train_top17.flatten())
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.857, total=   0.8s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.845, total=   0.6s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.852, total=   0.7s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.824, total=   0.8s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.836, total=   0.7s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.893, total=   4.3s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   4.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.892, total=   4.4s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   4.3s
# [CV] C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=1, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.881, total=   3.9s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.863, total=   0.6s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.847, total=   0.5s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.850, total=   0.5s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.830, total=   0.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.842, total=   0.8s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.888, total=   4.0s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.886, total=   4.0s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.896, total=   3.9s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.871, total=   3.7s
# [CV] C=1, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=balanced, penalty=none, score=0.881, total=   3.8s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.857, total=   0.7s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.844, total=   0.5s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.852, total=   0.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.823, total=   0.6s
# [CV] C=1, class_weight=None, penalty=l2 ..............................
# [CV] .. C=1, class_weight=None, penalty=l2, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.891, total=   4.2s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.884, total=   4.5s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.892, total=   4.5s
# [CV] C=1, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=1, class_weight=None, penalty=none, score=0.870, total=   4.4s
# [CV] C=1, class_weight=None, penalty=none ............................
# [CV]  C=1, class_weight=None, penalty=none, score=0.881, total=   3.8s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.881, total=   1.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.859, total=   1.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.866, total=   1.2s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.848, total=   1.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ................
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.856, total=   1.5s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.893, total=   4.3s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   4.5s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.892, total=   4.4s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   4.0s
# [CV] C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none ..............
# [CV]  C=5, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.881, total=   3.7s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.885, total=   1.0s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.859, total=   1.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.867, total=   1.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.848, total=   1.3s
# [CV] C=5, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=5, class_weight=balanced, penalty=l2, score=0.863, total=   1.1s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.888, total=   4.4s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.886, total=   4.2s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.896, total=   4.3s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.871, total=   4.4s
# [CV] C=5, class_weight=balanced, penalty=none ........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=5, class_weight=balanced, penalty=none, score=0.881, total=   4.4s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.881, total=   1.2s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.859, total=   1.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.867, total=   1.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.846, total=   1.3s
# [CV] C=5, class_weight=None, penalty=l2 ..............................
# [CV] .. C=5, class_weight=None, penalty=l2, score=0.856, total=   1.3s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.891, total=   4.5s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.884, total=   4.4s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.892, total=   4.1s
# [CV] C=5, class_weight=None, penalty=none ............................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=5, class_weight=None, penalty=none, score=0.870, total=   4.2s
# [CV] C=5, class_weight=None, penalty=none ............................
# [CV]  C=5, class_weight=None, penalty=none, score=0.881, total=   3.7s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.891, total=   1.7s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.864, total=   1.3s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.869, total=   1.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.852, total=   1.6s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.865, total=   1.4s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.893, total=   4.3s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   4.4s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.892, total=   4.3s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   4.3s
# [CV] C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# [CV]  C=10, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.881, total=   3.7s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.892, total=   1.6s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.868, total=   1.6s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.871, total=   1.8s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.864, total=   1.7s
# [CV] C=10, class_weight=balanced, penalty=l2 .........................
# [CV]  C=10, class_weight=balanced, penalty=l2, score=0.871, total=   1.8s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.888, total=   4.2s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.886, total=   3.8s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.896, total=   4.0s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.871, total=   4.1s
# [CV] C=10, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, class_weight=balanced, penalty=none, score=0.881, total=   3.9s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.891, total=   1.2s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.864, total=   1.3s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.870, total=   1.4s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.854, total=   1.5s
# [CV] C=10, class_weight=None, penalty=l2 .............................
# [CV] . C=10, class_weight=None, penalty=l2, score=0.864, total=   1.5s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.891, total=   4.3s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.884, total=   4.5s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.892, total=   4.4s
# [CV] C=10, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=10, class_weight=None, penalty=none, score=0.870, total=   4.4s
# [CV] C=10, class_weight=None, penalty=none ...........................
# [CV]  C=10, class_weight=None, penalty=none, score=0.881, total=   3.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.894, total=   2.4s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.883, total=   2.7s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.878, total=   2.4s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.869, total=   2.6s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2 ...............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=l2, score=0.883, total=   2.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.893, total=   4.5s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.884, total=   3.9s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.892, total=   4.3s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.869, total=   3.7s
# [CV] C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none .............
# [CV]  C=50, class_weight={0: 1, 1: 1, 2: 2}, penalty=none, score=0.881, total=   3.2s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.890, total=   2.4s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.881, total=   2.3s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.884, total=   2.8s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.871, total=   2.2s
# [CV] C=50, class_weight=balanced, penalty=l2 .........................
# [CV]  C=50, class_weight=balanced, penalty=l2, score=0.880, total=   2.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.888, total=   4.0s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.886, total=   4.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.896, total=   4.5s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.871, total=   4.3s
# [CV] C=50, class_weight=balanced, penalty=none .......................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=50, class_weight=balanced, penalty=none, score=0.881, total=   4.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.894, total=   2.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.883, total=   2.5s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.879, total=   3.1s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.869, total=   2.4s
# [CV] C=50, class_weight=None, penalty=l2 .............................
# [CV] . C=50, class_weight=None, penalty=l2, score=0.884, total=   2.7s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.891, total=   4.4s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.884, total=   4.5s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.892, total=   4.4s
# [CV] C=50, class_weight=None, penalty=none ...........................
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1321: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# [CV]  C=50, class_weight=None, penalty=none, score=0.870, total=   4.2s
# [CV] C=50, class_weight=None, penalty=none ...........................
# [CV]  C=50, class_weight=None, penalty=none, score=0.881, total=   3.7s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  5.7min finished
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(estimator=LogisticRegression(max_iter=1000),
#              param_grid={'C': [1, 5, 10, 50],
#                          'class_weight': [{0: 1, 1: 1, 2: 2}, 'balanced', None],
#                          'penalty': ['l2', 'none']},
#              verbose=3)

# %%
print(grid2_top17.best_params_)
print(grid2_top17.best_score_)
# Out:
# {'C': 1, 'class_weight': 'balanced', 'penalty': 'none'}
# 0.8844140912100947

# %%
# Make predictions with the hypertuned model
predictions_top17 = grid2_top17.predict(X_test_scaled_top17)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test_top17.flatten(), predictions_top17,
                            target_names=["CANDIDATE", "CONFIRMED","FALSE POSITIVE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.79      0.71      0.75       411
#      CONFIRMED       0.78      0.83      0.80       484
# FALSE POSITIVE       0.98      0.99      0.99       853
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.84      0.85      1748
#   weighted avg       0.88      0.88      0.88      1748

# %%
hypertuned_model_top17 = LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')
hypertuned_model_top17
# Out:
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')

# %%
hypertuned_model_top17.fit(X_train_scaled_top17, y_train_top17.flatten())
# Out:
# C:\Users\dalsa\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000, penalty='none')

# %%
print(f"Training Data Score: {hypertuned_model_top17.score(X_train_scaled_top17, y_train_top17)}")
print(f"Testing Data Score: {hypertuned_model_top17.score(X_test_scaled_top17, y_test_top17)}")
# Out:
# Training Data Score: 0.885752431813847
# Testing Data Score: 0.8804347826086957

# %% [markdown]
# # Save the Model

# %%
import joblib
filename = 'LogisticRegression.sav'
joblib.dump(hypertuned_model_top17, filename)
# Out:
# ['LogisticRegression.sav']
